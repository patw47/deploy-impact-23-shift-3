# %%
# !pip install lxml
# !pip install beautifulsoup4
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/tanyagolubev/.pyenv/versions/3.9.16/bin/python3.9 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/tanyagolubev/.pyenv/versions/3.9.16/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pandas as pd 
import numpy as np
from bs4 import BeautifulSoup
import re

# %%
df = pd.read_csv("/Users/tanyagolubev/Projects/deploy-impact-23-shift-3/data/glassdore/glassdoor.csv")

# %%
df.head(20).T
# Out:
#                                       0                    1       2       3   \
# benefits.benefitRatingDecimal        0.0                  4.0     0.0     0.0
# benefits.comments                 2801.0               2802.0  2803.0  2804.0
# benefits.highlights               2801.0               2802.0  2803.0  2804.0
# benefits.numRatings                    0                    3       0       0
# benefits.employerSummary             NaN                  NaN     NaN     NaN
# ...                                  ...                  ...     ...     ...
# salary.currency.positiveTemplate     NaN                   $#     NaN     NaN
# salary.currency.symbol               NaN              &pound;     NaN     NaN
# salary.lastSalaryDate                NaN  2019-10-14T06:05:58     NaN     NaN
# salary.salaries                   2483.0               2484.0  2485.0  2486.0
# wwfu                                 NaN                  NaN     NaN     NaN
#
# ...

# %%
df.filter(
    items = [
    'header.jobTitle', 
    'header.employerName', 
    'header.location', 
    'job.description', 
    'job.jobTitleId', 
    'map.country',
    'map.employerName',
    'map.lat',
    'map.lng',
    'map.location',
    'map.address',
    'map.postalCode',
    'overview.industry',
    'overview.description',
    'overview.mission',
    'overview.website',
        ]
).T
# Out:
#                                                                    0       \
# header.jobTitle                        Biogas Project Development Manager
# gaTrackerData.jobTitle                 Biogas Project Development Manager
# header.employerName                                           Modus Group
# header.location                                                    Warsaw
# job.jobTitleId                                                         -1
# map.country                                                        Poland
# map.employerName                                              Modus Group
# map.lat                                                             52.25
# map.lng                                                              21.0
# map.location                                                       Warsaw
# map.address                                                           NaN
# map.postalCode                                                        NaN
# ...

# %%
df[df['header.location']!=df['gaTrackerData.location']][['header.location','gaTrackerData.location']]
# Out:
#        header.location gaTrackerData.location
# 1                Porto                    NaN
# 2                Milan                 Milano
# 3              Karāchi                Karachi
# 5             Colombia                    NaN
# 6              Central                    NaN
# ...                ...                    ...
# 165278          Zürich                    NaN
# 165282       Tipperary                    NaN
# 165284     Nyíregyháza                    NaN
# 165285         Vietnam                    NaN
# 165289       Singapore                    NaN
#
# [92473 rows x 2 columns]

# %%
df[df["map.country"]=='CH']
# Out:
#         benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 279                          0.000000             3080.0               3080.0
# 338                          4.200000             3139.0               3139.0
# 419                          0.000000             8420.0               8420.0
# 436                          0.000000             8437.0               8437.0
# 498                          0.000000             8499.0               8499.0
# ...                               ...                ...                  ...
# 164944                       0.000000            58055.0              58055.0
# 164992                       0.000000            58103.0              58103.0
# 165154                       2.333333            58265.0              58265.0
# 165206                       0.000000            58317.0              58317.0
# 165254                       0.000000            58365.0              58365.0
#
# ...

# %%
tech_keywords = [
    'Computer',
    'Vision',
    'Developer',
    'Data',
    'Information',
    'Software',
    'Database',
    'Programming',
    'AI',
    'ML',
    'Application'
          ]

# %%
df['IT_job'] = df['header.jobTitle'].str.contains('|'.join(tech_keywords))

# %%
df['Swiss_based'] = np.where(df["map.country"] == "Switzerland", True, False)

# %%
df['Swiss_based'] = df["map.country"].map(lambda x: x=="Switzerland" or x=="CH")

# %%
df['Swiss_based'].value_counts()
# Out:
# Swiss_based
# False    162649
# True       2641
# Name: count, dtype: int64

# %%
#df_Swiss_IT = df.query('Swiss_based==True & IT_job == 900')
df_Swiss_IT  = df.loc[(df['Swiss_based'] ==True) & (df['IT_job'] == True)]

# %%
import re 
extract = df_Swiss_IT['job.description'].head(1).values[0]
extract_2 = df_Swiss_IT['job.description'][3:4].values[0]
extract_2
# Out:
# 'Although you will be exposed to all the different components, your focus will be one of the applications. You will be working on new features, help define the architecture and make sure our solutions stay maintainable (refactor when necessary).\n<br/><br/>\nYou will mainly be responsible for one of the following components:\n<br/><br/>\nDesktop Application with NFC (Electron)\n<br/>\nMobile Application (React Native with Bluetooth Low Energy)\n<br/>\nFrontend Applications (VueJS)\n<br/>\nBackend (Go)\n<br/>\nOther technologies and tools we are currently using are Python, Solidity and Docker as well as Git with Bitbucket, CI/CD for automated testing and deployment, JIRA, Slack, Confluence and Postgres. As a team we work in sprints, prioritize and define how to implement features together, do code reviews and always try to assist each other.\n<br/><br/>\n<strong>What you will be doing:</strong>\n<br/>\nDeveloping new features during development sprints, making sure your code is proper
# ...

# %% [markdown]
# df_Swiss_IT['job.description']

# %%
df_Swiss_IT['job.description'][3:4]
# Out:
# 632    Although you will be exposed to all the different components, your focus will be one of the applications. You will be working on new features, help define the architecture and make sure our solutions stay maintainable (refactor when necessary).\n<br/><br/>\nYou will mainly be responsible for one of the following components:\n<br/><br/>\nDesktop Application with NFC (Electron)\n<br/>\nMobile Application (React Native with Bluetooth Low Energy)\n<br/>\nFrontend Applications (VueJS)\n<br/>\nBackend (Go)\n<br/>\nOther technologies and tools we are currently using are Python, Solidity and Docker as well as Git with Bitbucket, CI/CD for automated testing and deployment, JIRA, Slack, Confluence and Postgres. As a team we work in sprints, prioritize and define how to implement features together, do code reviews and always try to assist each other.\n<br/><br/>\n<strong>What you will be doing:</strong>\n<br/>\nDeveloping new features during development sprints, making sure your code is 
# ...

# %%
pd.set_option("display.max_colwidth", None)

# %%
bs_result = BeautifulSoup(extract_2, 'lxml').text
result = re.sub('\n', ' ', bs_result)

# %%
result
# Out:
# 'Although you will be exposed to all the different components, your focus will be one of the applications. You will be working on new features, help define the architecture and make sure our solutions stay maintainable (refactor when necessary).You will mainly be responsible for one of the following components:Desktop Application with NFC (Electron)Mobile Application (React Native with Bluetooth Low Energy)Frontend Applications (VueJS)Backend (Go)Other technologies and tools we are currently using are Python, Solidity and Docker as well as Git with Bitbucket, CI/CD for automated testing and deployment, JIRA, Slack, Confluence and Postgres. As a team we work in sprints, prioritize and define how to implement features together, do code reviews and always try to assist each other.What you will be doing:Developing new features during development sprints, making sure your code is properly tested and documentedReviewing pull requests from your colleagues and discuss how issues can be solve
# ...

# %%
extract_2
# Out:
# 'Although you will be exposed to all the different components, your focus will be one of the applications. You will be working on new features, help define the architecture and make sure our solutions stay maintainable (refactor when necessary).\n<br/><br/>\nYou will mainly be responsible for one of the following components:\n<br/><br/>\nDesktop Application with NFC (Electron)\n<br/>\nMobile Application (React Native with Bluetooth Low Energy)\n<br/>\nFrontend Applications (VueJS)\n<br/>\nBackend (Go)\n<br/>\nOther technologies and tools we are currently using are Python, Solidity and Docker as well as Git with Bitbucket, CI/CD for automated testing and deployment, JIRA, Slack, Confluence and Postgres. As a team we work in sprints, prioritize and define how to implement features together, do code reviews and always try to assist each other.\n<br/><br/>\n<strong>What you will be doing:</strong>\n<br/>\nDeveloping new features during development sprints, making sure your code is proper
# ...
